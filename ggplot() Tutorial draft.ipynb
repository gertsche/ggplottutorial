# %%
# start by importing base python libraries
import pandas as pd
import numpy as np

# %%
import ggplot 
from ggplot import *
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-5f43a63c5283> in <module>
# ----> 1 import ggplot
#       2 from ggplot import *
#
# C:\Programs\lib\site-packages\ggplot\__init__.py in <module>
#      17
#      18
# ---> 19 from .geoms import geom_area, geom_blank, geom_boxplot, geom_line, geom_point, geom_jitter, geom_histogram, geom_density, geom_hline, geom_vline, geom_bar, geom_abline, geom_tile, geom_rect, geom_bin2d, geom_step, geom_text, geom_path, geom_ribbon, geom_now_its_art, geom_violin, geom_errorbar, geom_polygon
#      20 from .stats import stat_smooth, stat_density
#      21
#
# C:\Programs\lib\site-packages\ggplot\geoms\__init__.py in <module>
# ----> 1 from .geom_abline import geom_abline
#       2 from .geom_area import geom_area
#       3 from .geom_bar import geom_bar
#       4 from .geom_bin2d import geom_bin2d
# ...

# %%
# uh oh, it doesn't work. what else can we use?

# %%
# pip install plotnine

# %%
from plotnine import *

# %%
from pandas.api.types import CategoricalDtype
from plotnine.data import mpg, mtcars, diamonds

# %%
# used to counter depreciation warnings
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
(ggplot(mpg)         # defining what data to use
 + aes(x='class')    # defining what variable to use
 + geom_bar(size=20) # defining the type of plot to use
)

# in R, indentation is important to good style
# need to use parentheses in python because it doesn't recognize code spilling over onto multiple lines
# Out:
# <ggplot: (137463849697)>

# %%
(ggplot(mpg)
 + aes(x='class')
 + geom_bar(size=20)
 + coord_flip()        # flipping the x- and y-axes
 + labs(title='Number of Vehicles per Class', x='Vehicle Class', y='Number of Vehicles') # customizing labels
)

# adding more customization
# Out:
# <ggplot: (137465399798)>

# %%
(ggplot(mtcars) 
    + aes(x='wt',y='mpg')
    + geom_point()
    + xlab('Weight (1000s of lbs)') 
    + ylab('Miles per Gallon') 
    + geom_smooth(colour = 'red')
)

# another example, this time using a scatterplot
# Out:
# <ggplot: (137465347718)>

# %%
(ggplot(diamonds) 
    + aes(x = 'carat')
    + geom_histogram()
    + xlab('Number of Carats') 
    + ylab('Frequency') 
)
# Out:
# <ggplot: (137465378480)>
